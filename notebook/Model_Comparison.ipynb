# %%
import sys
sys.path.append('../src/')
from train import *
dataset = 'lilac'
image_type = 'adaptive'
eps = 10
delta = 10
width = 50
batch_size = 16
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2bfe4c72f19e> in <module>
#       1 import sys
#       2 sys.path.append('../src/')
# ----> 3 from train import *
#       4 dataset = 'lilac'
#       5 image_type = 'adaptive'
#
# /data/qypAWRG4NILM/src/train.py in <module>
# ----> 1 import torch
#       2 import numpy as np
#       3 import sys
#       4 from trainer import *
#       5 from datetime import datetime
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## CNN for LILAC

# %%
# create_trainer()
model_name = 'CNN'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_c, file_name_c = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_c)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_c,file_name_c)
# Out:
# processed: 4: : 3it [00:00, 29.81it/s]
# Load lilac aggregated data from ../data/lilac/aggregated/
# correct labels for some appliances
# processed: 1324: : 1324it [00:40, 32.87it/s]
#   0%|          | 0/63 [00:00<?, ?it/s]
# Trainer for lilac created.
# ...
# Epoch 99: 100%|██████████| 63/63 [00:02<00:00, 27.00it/s, loss=0.062, score=0.985]

# %% [markdown]
# ## ResNet18 for LILAC

# %%
# create_trainer()
model_name = 'ResNet18'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r18, file_name_r18 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r18)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r18,file_name_r18)
# Out:
# processed: 1324: : 1324it [00:12, 103.91it/s]
# ...
# Epoch 30:  56%|█████▌    | 35/63 [00:44<00:35,  1.26s/it, loss=0.044, score=0.991]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6ee48ced6e0e> in <module>
#       6 # train_the_model()
#       7 epochs = 100
# ----> 8 checkpoint_r18, file_name_r18 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
#       9 plot_learning_curve(file_name_r18)
#      10
#
# E:\_reVolt\codes\qypAWRG4NILM\src\train.py in train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension)
#      89
#      90     # start training
# ---> 91     time_used, train_loss, train_acc,  test_loss, test_acc = trainer.train(epochs,  csv_logger, checkpoint, file_name)
#      92     stop_logging(f)
#      93
#
# ...

# %% [markdown]
# ## ResNet34 for LILAC

# %%
# create_trainer()
model_name = 'ResNet34'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r34, file_name_r34 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r34)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r34,file_name_r34)
# Out:
# Input l for lilac, p for plaid)l
# Input a for AWRG, v for VI-grapthv
# Input epsilon (suggest 10):10
# Input delta (suggest 10):10
# Input width (suggest 50):50
# processed: 1324: : 1324it [00:02, 542.62it/s]
# processed: 1324: : 1324it [00:02, 543.61it/s]
# processed: 1324: : 1324it [00:02, 543.04it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:02<00:00, 27.36it/s, loss=0.007, score=0.998]

# %% [markdown]
# ## ResNet50 for LILAC

# %%
# create_trainer()
model_name = 'ResNet50'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r50, file_name_r50 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r50)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r18,file_name_r50)
# Out:
# Input l for lilac, p for plaid)l
# Input a for AWRG, v for VI-grapthv
# Input epsilon (suggest 10):10
# Input delta (suggest 10):10
# Input width (suggest 50):50
# processed: 1324: : 1324it [00:02, 542.62it/s]
# processed: 1324: : 1324it [00:02, 543.61it/s]
# processed: 1324: : 1324it [00:02, 543.04it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:02<00:00, 27.36it/s, loss=0.007, score=0.998]

# %% [markdown]
# ## ResNet101 for LILAC

# %%
# create_trainer()
model_name = 'ResNet101'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r101, file_name_r101 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r101)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r101,file_name_r101)
# Out:
# Input l for lilac, p for plaid)l
# Input a for AWRG, v for VI-grapthv
# Input epsilon (suggest 10):10
# Input delta (suggest 10):10
# Input width (suggest 50):50
# processed: 1324: : 1324it [00:02, 542.62it/s]
# processed: 1324: : 1324it [00:02, 543.61it/s]
# processed: 1324: : 1324it [00:02, 543.04it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:02<00:00, 27.36it/s, loss=0.007, score=0.998]

# %% [markdown]
# ## ResNet152 for LILAC

# %%
# create_trainer()
model_name = 'ResNet152'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r152, file_name_r152 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r152)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r152,file_name_r152)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe9345ca50a1> in <module>
#       1 # create_trainer()
#       2 model_name = 'ResNet152'
# ----> 3 num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size,
#       4                                     width=width, eps=eps, delta=delta)
#       5
#
# NameError: name 'create_trainer' is not defined
