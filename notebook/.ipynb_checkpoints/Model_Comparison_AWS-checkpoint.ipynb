# %%
import sys
sys.path.append('../src/')
from train import *
dataset = 'lilac'
image_type = 'adaptive'
eps = 10
delta = 10
width = 50
batch_size = 16

# %% [markdown]
# ## CNN for LILAC

# %%
# create_trainer()
model_name = 'CNN'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_c, file_name_c = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_c)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_c,file_name_c)
# Out:
# processed: 11: : 10it [00:00, 65.41it/s]
# Load lilac aggregated data from ../data/lilac/aggregated/
# correct labels for some appliances
# processed: 1324: : 1324it [00:15, 84.43it/s]
# Epoch 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Trainer for lilac created.
# ...
# Epoch 99: 100%|██████████| 63/63 [00:00<00:00, 93.52it/s, loss=0.063, score=0.987]

# %% [markdown]
# ## ResNet18 for LILAC

# %%
# create_trainer()
model_name = 'ResNet18'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r18, file_name_r18 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r18)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r18,file_name_r18)
# Out:
# processed: 1324: : 1324it [00:15, 84.93it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:12<00:00,  5.02it/s, loss=0.009, score=0.997]

# %% [markdown]
# ## ResNet34 for LILAC

# %%
# create_trainer()
model_name = 'ResNet34'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r34, file_name_r34 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r34)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r34,file_name_r34)
# Out:
# processed: 1324: : 1324it [00:15, 84.05it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:28<00:00,  2.21it/s, loss=0.013, score=0.996]

# %% [markdown]
# ## ResNet50 for LILAC

# %%
# create_trainer()
model_name = 'ResNet50'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r50, file_name_r50 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r50)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r50,file_name_r50)
# Out:
# processed: 1324: : 1324it [00:16, 82.32it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:39<00:00,  1.59it/s, loss=0.031, score=0.994]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-92a1c3b92178> in <module>()
#      10
#      11 # test_the_model()
# ---> 12 test_the_model(trainer, num_class, checkpoint_r18,file_name_r50)
#
# /data/qypAWRG4NILM/src/train.py in test_the_model(trainer, num_class, checkpoint, file_name)
#     116
#     117 def test_the_model(trainer, num_class, checkpoint, file_name):
# --> 118     f1, mcc, zl = trainer.test(num_class, checkpoint)
#     119     filename = file_name+'_{}'.format(datetime.utcnow().strftime('%m-%d-%H-%M'))
#     120     f = open('../results/{}.txt'.format(filename), 'w')
#
# /data/qypAWRG4NILM/src/trainer.py in test(self, num_class, checkpoint)
#     185     def test(self, num_class, checkpoint):
# ...

# %%
# test_the_model()
test_the_model(trainer, num_class, checkpoint_r50,file_name_r50)

# %% [markdown]
# ## ResNet101 for LILAC

# %%
# create_trainer()
model_name = 'ResNet101'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r101, file_name_r101 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r101)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r101,file_name_r101)
# Out:
# processed: 1324: : 1324it [00:16, 77.94it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [01:28<00:00,  1.41s/it, loss=0.051, score=0.993]

# %% [markdown]
# ## ResNet152 for LILAC

# %%
# create_trainer()
model_name = 'ResNet152'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_r152, file_name_r152 = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_r152)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_r152,file_name_r152)
# Out:
# 0it [00:00, ?it/s]
# Load lilac aggregated data from ../data/lilac/aggregated/
# correct labels for some appliances
# processed: 1324: : 1324it [00:15, 83.76it/s]
# Epoch 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Trainer for lilac created.
# ...
# Epoch 99: 100%|██████████| 63/63 [02:09<00:00,  2.06s/it, loss=0.055, score=0.991]

# %% [markdown]
# ## EfficientNet v2 small for LILAC

# %%
# create_trainer()
model_name = 'EffiNet_small'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_es, file_name_es = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_es)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_es,file_name_es)
# Out:
# processed: 1324: : 1324it [00:15, 84.26it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:13<00:00,  4.77it/s, loss=0.078, score=0.994]

# %% [markdown]
# ## EfficientNet v2  medium for LILAC

# %%
# create_trainer()
model_name = 'EffiNet_medium'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_em, file_name_em = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_em)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_em,file_name_em)
# Out:
# processed: 10: : 9it [00:00, 68.84it/s]
# Load lilac aggregated data from ../data/lilac/aggregated/
# correct labels for some appliances
# processed: 1324: : 1324it [00:15, 85.65it/s]
# Epoch 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Trainer for lilac created.
# ...
# Epoch 99: 100%|██████████| 63/63 [00:16<00:00,  3.81it/s, loss=0.067, score=0.993]

# %% [markdown]
# ## EfficientNet v2 large for LILAC

# %%
# create_trainer()
model_name = 'EffiNet_large'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_el, file_name_el = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_el)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_el,file_name_el)
# Out:
# processed: 1324: : 1324it [00:15, 84.02it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:25<00:00,  2.51it/s, loss=0.070, score=0.990]

# %% [markdown]
# ## EfficientNet v2 exlarge for LILAC

# %%
# create_trainer()
model_name = 'EffiNet_extra_large'
num_class, trainer = create_trainer(dataset=dataset, image_type=image_type, model_name=model_name, multi_dimension=True, batch_size=batch_size, 
                                    width=width, eps=eps, delta=delta)

# train_the_model()
epochs = 100
checkpoint_exl, file_name_exl = train_the_model(trainer, dataset, image_type, model_name, epochs, width, multi_dimension=True)
plot_learning_curve(file_name_exl)

# test_the_model()
test_the_model(trainer, num_class, checkpoint_exl,file_name_exl)
# Out:
# processed: 1324: : 1324it [00:16, 82.16it/s]
# ...
# Epoch 99: 100%|██████████| 63/63 [00:48<00:00,  1.29it/s, loss=0.084, score=0.990]
